# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Pandas:
# - Series
# - Dataframe

# %%
X = [2,4,6,8,0]

# %%
import pandas as pd

# %%
thing = pd.Series(X)
thing
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# 4    0
# dtype: int64

# %%
data = {
    'name': ['Rob', 'Nirosh', 'Jeni'],
    'age' : [30,31,29]    
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      name  age
# 0     Rob   30
# 1  Nirosh   31
# 2    Jeni   29

# %%
df['newcolname'] = 2
df
# Out:
#      name  age  newcolname
# 0     Rob   30           2
# 1  Nirosh   31           2
# 2    Jeni   29           2

# %%
df.loc[(df['name']=='Rob') & (df['age']>20), :]
# Out:
#   name  age
# 0  Rob   30

# %%
# REMEMBER:
#df.loc[ROWS,COLS]

# : means everything

# %%
df.loc[:,'age']
# Out:
# 0    30
# 1    31
# 2    29
# Name: age, dtype: int64
